# %%
from tensorflow import keras
# Out:
# 2024-05-02 17:58:49.235936: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-02 17:58:49.769884: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 17:58:49.770239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 17:58:49.861706: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
model = keras.saving.load_model("custom_mobilenet_best_224.keras")
# Out:
# 2024-05-02 17:59:35.244355: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-02 17:59:35.466550: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-02 17:59:35.466587: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-02 17:59:35.473872: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
model2 = keras.models.load_model("custom_mobilenet_best_224.keras")

# %%
model.layers

# %%
import matplotlib.pyplot as plt
import numpy as np

img = plt.imread("data/test/ABYSSINIAN GROUND HORNBILL/1.jpg")
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
np.expand_dims(img, 0).dtype
# Out:
# dtype('uint8')

# %%
out = model.predict(np.expand_dims(img, 0))
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
out.shape
# Out:
# (1, 525)

# %%
np.argmax(out, axis=1)
# Out:
# array([486])

# %%
np.max(out)
# Out:
# 0.4440886

# %%
np.sum(out)
# Out:
# 1.0
