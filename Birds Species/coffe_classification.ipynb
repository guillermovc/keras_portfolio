# %% [markdown]
# # Clasificación de imágenes
#
# Basado en [TUTORIAL TENSORFLOW](https://www.tensorflow.org/tutorials/images/classification?hl=es-419#download_and_explore_the_dataset)

# %% [markdown]
# Este tutorial muestra cómo clasificar imágenes de flores. Crea un clasificador de imágenes usando un modelo tf.keras.Sequential y carga datos usando tf.keras.utils.image_dataset_from_directory . Adquirirás experiencia práctica con los siguientes conceptos:
#
# * Carga eficiente de un conjunto de datos fuera del disco.
# * Identificar el sobreajuste y aplicar técnicas para mitigarlo, incluido el aumento y la eliminación de datos.
#
# Este tutorial sigue un flujo de trabajo básico de aprendizaje automático:
#
# 1. Examinar y comprender los datos.
# 1. Crear una canalización de entrada
# 1. Construye el modelo
# 1. entrenar al modelo
# 1. Probar el modelo
# 1. Mejorar el modelo y repetir el proceso

# %% [markdown]
# # Descargar el conjunto de datos de flores
# Este tutorial utiliza un conjunto de datos de varios miles de fotos de flores. El conjunto de datos de flores contiene cinco subdirectorios, uno por clase:

# %% [markdown]
# ```
# flowers_photos/
#   daisy/
#   dandelion/
#   roses/
#   sunflowers/
#   tulips/
# ```

# %% [markdown]
# ## Cargar variables para la API de Kaggle

# %% [markdown]
# Descargar el .json y moverlo a la ruta /root/.kaggle

# %%
# !mkdir -p /keras_portfolio/"Birds Species"/data/

# %%
# !kaggle datasets download -d gpiosenka/100-bird-species -p /keras_portfolio/"Birds Species"/data/
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading 100-bird-species.zip to /keras_portfolio/Birds Species/data
# ... resuming from 30408704 bytes (2069219745 bytes left) ...
#   5%|█▌                                 | 91.0M/1.96G [41:50<23:23:57, 23.8kB/s]^C
#   5%|█▌                                 | 91.0M/1.96G [41:53<21:31:33, 25.9kB/s]
# User cancelled operation

# %%
# !unzip -q /keras_portfolio/"Birds Species"/data/100-bird-species.zip -d /keras_portfolio/"Birds Species"/data/
# Out:
# Archive:  /keras_portfolio/data/coffee-bean-dataset-resized-224-x-224.zip
#   inflating: /keras_portfolio/data/Coffee Bean.csv
#   inflating: /keras_portfolio/data/test/Dark/dark (1).png
#   inflating: /keras_portfolio/data/test/Dark/dark (10).png
#   inflating: /keras_portfolio/data/test/Dark/dark (100).png
#   inflating: /keras_portfolio/data/test/Dark/dark (11).png
#   inflating: /keras_portfolio/data/test/Dark/dark (12).png
#   inflating: /keras_portfolio/data/test/Dark/dark (13).png
#   inflating: /keras_portfolio/data/test/Dark/dark (14).png
#   inflating: /keras_portfolio/data/test/Dark/dark (15).png
#   inflating: /keras_portfolio/data/test/Dark/dark (16).png
#   inflating: /keras_portfolio/data/test/Dark/dark (17).png
#   inflating: /keras_portfolio/data/test/Dark/dark (18).png
#   inflating: /keras_portfolio/data/test/Dark/dark (19).png
#   inflating: /keras_portfolio/data/test/Dark/dark (2).png
#   inflating: /keras_portfolio/data/test/Dark/dark (20).png
#   inflating: /keras_portfolio/data/test/Dark/dark (21).png
#   inflating: /keras_portfolio/data/test/Dark/dark (22).png
#   inflating: /keras_portfolio/data/test/Dark/dark (23).png
#   inflating: /keras_portfolio/data/test/Dark/dark (24).png
#   inflating: /keras_portfolio/data/train/Green/green (143).png
#   inflating: /keras_portfolio/data/train/Green/green (144).png
#   inflating: /keras_portfolio/data/train/Green/green (145).png
#   inflating: /keras_portfolio/data/train/Green/green (146).png
#   inflating: /keras_portfolio/data/train/Green/green (147).png
#   inflating: /keras_portfolio/data/train/Green/green (148).png
#   inflating: /keras_portfolio/data/train/Green/green (149).png
#   inflating: /keras_portfolio/data/train/Green/green (15).png
#   inflating: /keras_portfolio/data/train/Green/green (150).png
#   inflating: /keras_portfolio/data/train/Green/green (151).png
#   inflating: /keras_portfolio/data/train/Green/green (152).png
# ...
#   inflating: /keras_portfolio/data/train/Medium/medium (153).png
#   inflating: /keras_portfolio/data/train/Medium/medium (154).png
#   inflating: /keras_portfolio/data/train/Medium/medium (155).png
#   inflating: /keras_portfolio/data/train/Medium/medium (156).png
#   inflating: /keras_portfolio/data/train/Medium/medium (157).png
#   inflating: /keras_portfolio/data/train/Medium/medium (158).png
#   inflating: /keras_portfolio/data/train/Medium/medium (159).png
#   inflating: /keras_portfolio/data/train/Medium/medium (16).png
#   inflating: /keras_portfolio/data/train/Medium/medium (160).png
#   inflating: /keras_portfolio/data/train/Medium/medium (161).png
#   inflating: /keras_portfolio/data/train/Medium/medium (162).png
#   inflating: /keras_portfolio/data/train/Medium/medium (163).png
#   inflating: /keras_portfolio/data/train/Medium/medium (164).png
#   inflating: /keras_portfolio/data/train/Medium/medium (165).png
#   inflating: /keras_portfolio/data/train/Medium/medium (166).png
#   inflating: /keras_portfolio/data/train/Medium/medium (167).png
#   inflating: /keras_portfolio/data/train/Medium/medium (168).png
#   inflating: /keras_portfolio/data/train/Medium/medium (169).png
#   inflating: /keras_portfolio/data/train/Medium/medium (17).png
#   inflating: /keras_portfolio/data/train/Medium/medium (170).png
#   inflating: /keras_portfolio/data/train/Medium/medium (171).png
#   inflating: /keras_portfolio/data/train/Medium/medium (172).png
#   inflating: /keras_portfolio/data/train/Medium/medium (173).png
#   inflating: /keras_portfolio/data/train/Medium/medium (174).png
#   inflating: /keras_portfolio/data/train/Medium/medium (175).png
#   inflating: /keras_portfolio/data/train/Medium/medium (176).png
#   inflating: /keras_portfolio/data/train/Medium/medium (177).png
#   inflating: /keras_portfolio/data/train/Medium/medium (178).png
#   inflating: /keras_portfolio/data/train/Medium/medium (179).png
#   inflating: /keras_portfolio/data/train/Medium/medium (18).png
#   inflating: /keras_portfolio/data/train/Medium/medium (180).png
#   inflating: /keras_portfolio/data/train/Medium/medium (181).png
#   inflating: /keras_portfolio/data/train/Medium/medium (182).png
#   inflating: /keras_portfolio/data/train/Medium/medium (183).png
#   inflating: /keras_portfolio/data/train/Medium/medium (184).png
#   inflating: /keras_portfolio/data/train/Medium/medium (185).png
#   inflating: /keras_portfolio/data/train/Medium/medium (186).png
#   inflating: /keras_portfolio/data/train/Medium/medium (187).png
#   inflating: /keras_portfolio/data/train/Medium/medium (188).png
#   inflating: /keras_portfolio/data/train/Medium/medium (189).png
#   inflating: /keras_portfolio/data/train/Medium/medium (19).png
#   inflating: /keras_portfolio/data/train/Medium/medium (190).png
#   inflating: /keras_portfolio/data/train/Medium/medium (191).png
#   inflating: /keras_portfolio/data/train/Medium/medium (192).png
#   inflating: /keras_portfolio/data/train/Medium/medium (193).png
#   inflating: /keras_portfolio/data/train/Medium/medium (194).png
#   inflating: /keras_portfolio/data/train/Medium/medium (195).png
#   inflating: /keras_portfolio/data/train/Medium/medium (196).png
#   inflating: /keras_portfolio/data/train/Medium/medium (197).png
#   inflating: /keras_portfolio/data/train/Medium/medium (198).png
#   inflating: /keras_portfolio/data/train/Medium/medium (199).png
#   inflating: /keras_portfolio/data/train/Medium/medium (2).png
#   inflating: /keras_portfolio/data/train/Medium/medium (20).png
#   inflating: /keras_portfolio/data/train/Medium/medium (200).png
#   inflating: /keras_portfolio/data/train/Medium/medium (201).png
#   inflating: /keras_portfolio/data/train/Medium/medium (202).png
#   inflating: /keras_portfolio/data/train/Medium/medium (203).png
#   inflating: /keras_portfolio/data/train/Medium/medium (204).png
#   inflating: /keras_portfolio/data/train/Medium/medium (205).png
#   inflating: /keras_portfolio/data/train/Medium/medium (206).png
#   inflating: /keras_portfolio/data/train/Medium/medium (207).png
#   inflating: /keras_portfolio/data/train/Medium/medium (208).png
#   inflating: /keras_portfolio/data/train/Medium/medium (209).png
#   inflating: /keras_portfolio/data/train/Medium/medium (21).png
#   inflating: /keras_portfolio/data/train/Medium/medium (210).png
#   inflating: /keras_portfolio/data/train/Medium/medium (211).png
#   inflating: /keras_portfolio/data/train/Medium/medium (212).png
#   inflating: /keras_portfolio/data/train/Medium/medium (213).png
#   inflating: /keras_portfolio/data/train/Medium/medium (214).png
#   inflating: /keras_portfolio/data/train/Medium/medium (215).png
#   inflating: /keras_portfolio/data/train/Medium/medium (216).png
#   inflating: /keras_portfolio/data/train/Medium/medium (217).png
#   inflating: /keras_portfolio/data/train/Medium/medium (218).png
#   inflating: /keras_portfolio/data/train/Medium/medium (219).png
#   inflating: /keras_portfolio/data/train/Medium/medium (22).png
#   inflating: /keras_portfolio/data/train/Medium/medium (220).png
#   inflating: /keras_portfolio/data/train/Medium/medium (221).png
#   inflating: /keras_portfolio/data/train/Medium/medium (222).png
#   inflating: /keras_portfolio/data/train/Medium/medium (223).png
#   inflating: /keras_portfolio/data/train/Medium/medium (224).png
#   inflating: /keras_portfolio/data/train/Medium/medium (225).png
#   inflating: /keras_portfolio/data/train/Medium/medium (226).png
#   inflating: /keras_portfolio/data/train/Medium/medium (227).png
#   inflating: /keras_portfolio/data/train/Medium/medium (228).png
#   inflating: /keras_portfolio/data/train/Medium/medium (229).png
#   inflating: /keras_portfolio/data/train/Medium/medium (23).png
#   inflating: /keras_portfolio/data/train/Medium/medium (230).png
#   inflating: /keras_portfolio/data/train/Medium/medium (231).png
#   inflating: /keras_portfolio/data/train/Medium/medium (232).png
#   inflating: /keras_portfolio/data/train/Medium/medium (233).png
#   inflating: /keras_portfolio/data/train/Medium/medium (234).png
#   inflating: /keras_portfolio/data/train/Medium/medium (235).png
#   inflating: /keras_portfolio/data/train/Medium/medium (236).png
#   inflating: /keras_portfolio/data/train/Medium/medium (237).png
#   inflating: /keras_portfolio/data/train/Medium/medium (238).png
#   inflating: /keras_portfolio/data/train/Medium/medium (239).png
#   inflating: /keras_portfolio/data/train/Medium/medium (24).png
#   inflating: /keras_portfolio/data/train/Medium/medium (240).png
#   inflating: /keras_portfolio/data/train/Medium/medium (241).png
#   inflating: /keras_portfolio/data/train/Medium/medium (242).png
#   inflating: /keras_portfolio/data/train/Medium/medium (243).png
#   inflating: /keras_portfolio/data/train/Medium/medium (244).png
#   inflating: /keras_portfolio/data/train/Medium/medium (245).png
#   inflating: /keras_portfolio/data/train/Medium/medium (246).png
#   inflating: /keras_portfolio/data/train/Medium/medium (247).png
#   inflating: /keras_portfolio/data/train/Medium/medium (248).png
#   inflating: /keras_portfolio/data/train/Medium/medium (249).png
#   inflating: /keras_portfolio/data/train/Medium/medium (25).png
#   inflating: /keras_portfolio/data/train/Medium/medium (250).png
#   inflating: /keras_portfolio/data/train/Medium/medium (251).png
#   inflating: /keras_portfolio/data/train/Medium/medium (252).png
#   inflating: /keras_portfolio/data/train/Medium/medium (253).png
#   inflating: /keras_portfolio/data/train/Medium/medium (254).png
#   inflating: /keras_portfolio/data/train/Medium/medium (255).png
#   inflating: /keras_portfolio/data/train/Medium/medium (256).png
#   inflating: /keras_portfolio/data/train/Medium/medium (257).png
#   inflating: /keras_portfolio/data/train/Medium/medium (258).png
#   inflating: /keras_portfolio/data/train/Medium/medium (259).png
#   inflating: /keras_portfolio/data/train/Medium/medium (26).png
#   inflating: /keras_portfolio/data/train/Medium/medium (260).png
#   inflating: /keras_portfolio/data/train/Medium/medium (261).png
#   inflating: /keras_portfolio/data/train/Medium/medium (262).png
#   inflating: /keras_portfolio/data/train/Medium/medium (263).png
#   inflating: /keras_portfolio/data/train/Medium/medium (264).png
#   inflating: /keras_portfolio/data/train/Medium/medium (265).png
#   inflating: /keras_portfolio/data/train/Medium/medium (266).png
#   inflating: /keras_portfolio/data/train/Medium/medium (267).png
#   inflating: /keras_portfolio/data/train/Medium/medium (268).png
#   inflating: /keras_portfolio/data/train/Medium/medium (269).png
#   inflating: /keras_portfolio/data/train/Medium/medium (27).png
#   inflating: /keras_portfolio/data/train/Medium/medium (270).png
#   inflating: /keras_portfolio/data/train/Medium/medium (271).png
#   inflating: /keras_portfolio/data/train/Medium/medium (272).png
#   inflating: /keras_portfolio/data/train/Medium/medium (273).png
#   inflating: /keras_portfolio/data/train/Medium/medium (274).png
#   inflating: /keras_portfolio/data/train/Medium/medium (275).png
#   inflating: /keras_portfolio/data/train/Medium/medium (276).png
#   inflating: /keras_portfolio/data/train/Medium/medium (277).png
#   inflating: /keras_portfolio/data/train/Medium/medium (278).png
#   inflating: /keras_portfolio/data/train/Medium/medium (279).png
#   inflating: /keras_portfolio/data/train/Medium/medium (28).png
#   inflating: /keras_portfolio/data/train/Medium/medium (280).png
#   inflating: /keras_portfolio/data/train/Medium/medium (281).png
#   inflating: /keras_portfolio/data/train/Medium/medium (282).png
#   inflating: /keras_portfolio/data/train/Medium/medium (283).png
#   inflating: /keras_portfolio/data/train/Medium/medium (284).png
#   inflating: /keras_portfolio/data/train/Medium/medium (285).png
#   inflating: /keras_portfolio/data/train/Medium/medium (286).png
#   inflating: /keras_portfolio/data/train/Medium/medium (287).png
#   inflating: /keras_portfolio/data/train/Medium/medium (288).png
#   inflating: /keras_portfolio/data/train/Medium/medium (289).png
#   inflating: /keras_portfolio/data/train/Medium/medium (29).png
#   inflating: /keras_portfolio/data/train/Medium/medium (290).png
#   inflating: /keras_portfolio/data/train/Medium/medium (291).png
#   inflating: /keras_portfolio/data/train/Medium/medium (292).png
#   inflating: /keras_portfolio/data/train/Medium/medium (293).png
#   inflating: /keras_portfolio/data/train/Medium/medium (294).png
#   inflating: /keras_portfolio/data/train/Medium/medium (295).png
#   inflating: /keras_portfolio/data/train/Medium/medium (296).png
#   inflating: /keras_portfolio/data/train/Medium/medium (297).png
#   inflating: /keras_portfolio/data/train/Medium/medium (298).png
#   inflating: /keras_portfolio/data/train/Medium/medium (299).png
#   inflating: /keras_portfolio/data/train/Medium/medium (3).png
#   inflating: /keras_portfolio/data/train/Medium/medium (30).png
#   inflating: /keras_portfolio/data/train/Medium/medium (300).png
#   inflating: /keras_portfolio/data/train/Medium/medium (31).png
#   inflating: /keras_portfolio/data/train/Medium/medium (32).png
#   inflating: /keras_portfolio/data/train/Medium/medium (33).png
#   inflating: /keras_portfolio/data/train/Medium/medium (34).png
#   inflating: /keras_portfolio/data/train/Medium/medium (35).png
#   inflating: /keras_portfolio/data/train/Medium/medium (36).png
#   inflating: /keras_portfolio/data/train/Medium/medium (37).png
#   inflating: /keras_portfolio/data/train/Medium/medium (38).png
#   inflating: /keras_portfolio/data/train/Medium/medium (39).png
#   inflating: /keras_portfolio/data/train/Medium/medium (4).png
#   inflating: /keras_portfolio/data/train/Medium/medium (40).png
#   inflating: /keras_portfolio/data/train/Medium/medium (41).png
#   inflating: /keras_portfolio/data/train/Medium/medium (42).png
#   inflating: /keras_portfolio/data/train/Medium/medium (43).png
#   inflating: /keras_portfolio/data/train/Medium/medium (44).png
#   inflating: /keras_portfolio/data/train/Medium/medium (45).png
#   inflating: /keras_portfolio/data/train/Medium/medium (46).png
#   inflating: /keras_portfolio/data/train/Medium/medium (47).png
#   inflating: /keras_portfolio/data/train/Medium/medium (48).png
#   inflating: /keras_portfolio/data/train/Medium/medium (49).png
#   inflating: /keras_portfolio/data/train/Medium/medium (5).png
#   inflating: /keras_portfolio/data/train/Medium/medium (50).png
#   inflating: /keras_portfolio/data/train/Medium/medium (51).png
#   inflating: /keras_portfolio/data/train/Medium/medium (52).png
#   inflating: /keras_portfolio/data/train/Medium/medium (53).png
#   inflating: /keras_portfolio/data/train/Medium/medium (54).png
#   inflating: /keras_portfolio/data/train/Medium/medium (55).png
#   inflating: /keras_portfolio/data/train/Medium/medium (56).png
#   inflating: /keras_portfolio/data/train/Medium/medium (57).png
#   inflating: /keras_portfolio/data/train/Medium/medium (58).png
#   inflating: /keras_portfolio/data/train/Medium/medium (59).png
#   inflating: /keras_portfolio/data/train/Medium/medium (6).png
#   inflating: /keras_portfolio/data/train/Medium/medium (60).png
#   inflating: /keras_portfolio/data/train/Medium/medium (61).png
#   inflating: /keras_portfolio/data/train/Medium/medium (62).png
#   inflating: /keras_portfolio/data/train/Medium/medium (63).png
#   inflating: /keras_portfolio/data/train/Medium/medium (64).png
#   inflating: /keras_portfolio/data/train/Medium/medium (65).png
#   inflating: /keras_portfolio/data/train/Medium/medium (66).png
#   inflating: /keras_portfolio/data/train/Medium/medium (67).png
#   inflating: /keras_portfolio/data/train/Medium/medium (68).png
#   inflating: /keras_portfolio/data/train/Medium/medium (69).png
#   inflating: /keras_portfolio/data/train/Medium/medium (7).png
#   inflating: /keras_portfolio/data/train/Medium/medium (70).png
#   inflating: /keras_portfolio/data/train/Medium/medium (71).png
#   inflating: /keras_portfolio/data/train/Medium/medium (72).png
#   inflating: /keras_portfolio/data/train/Medium/medium (73).png
#   inflating: /keras_portfolio/data/train/Medium/medium (74).png
#   inflating: /keras_portfolio/data/train/Medium/medium (75).png
#   inflating: /keras_portfolio/data/train/Medium/medium (76).png
#   inflating: /keras_portfolio/data/train/Medium/medium (77).png
#   inflating: /keras_portfolio/data/train/Medium/medium (78).png
#   inflating: /keras_portfolio/data/train/Medium/medium (79).png
#   inflating: /keras_portfolio/data/train/Medium/medium (8).png
#   inflating: /keras_portfolio/data/train/Medium/medium (80).png
#   inflating: /keras_portfolio/data/train/Medium/medium (81).png
#   inflating: /keras_portfolio/data/train/Medium/medium (82).png
#   inflating: /keras_portfolio/data/train/Medium/medium (83).png
#   inflating: /keras_portfolio/data/train/Medium/medium (84).png
#   inflating: /keras_portfolio/data/train/Medium/medium (85).png
#   inflating: /keras_portfolio/data/train/Medium/medium (86).png
#   inflating: /keras_portfolio/data/train/Medium/medium (87).png
#   inflating: /keras_portfolio/data/train/Medium/medium (88).png
#   inflating: /keras_portfolio/data/train/Medium/medium (89).png
#   inflating: /keras_portfolio/data/train/Medium/medium (9).png
#   inflating: /keras_portfolio/data/train/Medium/medium (90).png
#   inflating: /keras_portfolio/data/train/Medium/medium (91).png
#   inflating: /keras_portfolio/data/train/Medium/medium (92).png
#   inflating: /keras_portfolio/data/train/Medium/medium (93).png
#   inflating: /keras_portfolio/data/train/Medium/medium (94).png
#   inflating: /keras_portfolio/data/train/Medium/medium (95).png
#   inflating: /keras_portfolio/data/train/Medium/medium (96).png
#   inflating: /keras_portfolio/data/train/Medium/medium (97).png
#   inflating: /keras_portfolio/data/train/Medium/medium (98).png
#   inflating: /keras_portfolio/data/train/Medium/medium (99).png

# %%
# %cd /keras_portfolio/Coffee\ Classification
# Out:
# /keras_portfolio/Coffee Classification
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pwd
# Out:
# /keras_portfolio/Coffee Classification

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# 2024-04-09 01:20:17.968273: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-09 01:20:18.702794: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-09 01:20:18.703233: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-09 01:20:18.846801: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-09 01:20:19.163919: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
images = pd.read_csv("data/Coffee Bean.csv")

# %%
images.shape
# Out:
# (1600, 4)

# %%
images.head()
# Out:
#    class index                  filepaths labels data set
# 0            0    train/Dark/dark (1).png   Dark    train
# 1            0   train/Dark/dark (10).png   Dark    train
# 2            0  train/Dark/dark (100).png   Dark    train
# 3            0  train/Dark/dark (101).png   Dark    train
# 4            0  train/Dark/dark (102).png   Dark    train

# %%
images["data set"].value_counts(normalize=False)
# Out:
# data set
# train    1200
# test      400
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
images["data set"].value_counts(normalize=False).plot(kind="bar")
plt.xticks(rotation=0)
plt.title("Images count by subset")
plt.xlabel("Subset")
plt.ylabel("Image count")
plt.show()

# %%
images["class index"].value_counts(normalize=False)
# Out:
# class index
# 0    400
# 1    400
# 2    400
# 3    400
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
images["class index"].value_counts(normalize=False).plot(kind="bar")
plt.xticks(rotation=0)
plt.title("Class count")
plt.xlabel("Class")
plt.ylabel("Image count")
plt.show()

# %% [markdown]
# All classes have 400 instances

# %%
images.sample(9)
# Out:
#       class index                      filepaths  labels data set
# 1092            3  train/Medium/medium (272).png  Medium    train
# 912             3   train/Medium/medium (11).png  Medium    train
# 369             1    train/Green/green (161).png   Green    train
# 1410            2      test/Light/light (18).png   Light     test
# 761             2    train/Light/light (244).png   Light    train
# 970             3  train/Medium/medium (162).png  Medium    train
# 1359            1      test/Green/green (62).png   Green     test
# 1109            3  train/Medium/medium (288).png  Medium    train
# 1470            2      test/Light/light (72).png   Light     test

# %%
from pathlib import Path

dataset = Path("data")
colors = ['black', 'green', 'blue', 'red']

plt.figure(figsize=(6,6))
for i, row in enumerate(images.sample(9).iterrows()):
    class_id, filepath, label = row[1]["class index"], row[1]["filepaths"], row[1]["labels"]
    img = plt.imread(dataset / filepath)
    color = colors[class_id]

    plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.title(f"{label}", fontsize=10, color=color)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Cargue datos usando una utilidad Keras
#
# Carguemos estas imágenes fuera del disco utilizando la útil utilidad **tf.keras.utils.image_dataset_from_directory** . Esto lo llevará de un directorio de imágenes en el disco a un **tf.data.Dataset** en solo un par de líneas de código.

# %% [markdown]
# ## Crear un conjunto de datos
# Defina algunos parámetros para el cargador:

# %%
batch_size = 32
img_height = 128
img_width = 128

# %% [markdown]
# Es una buena práctica usar una división de validación al desarrollar su modelo. Usemos el 80% de las imágenes para entrenamiento y el 20% para validación.

# %%
from sklearn.model_selection import train_test_split

images = pd.read_csv("data/Coffee Bean.csv")
images["filepaths"] = images["filepaths"].apply(lambda x: str(dataset / x))
df_train = images[images['data set'] == 'train']
df_test = images[images['data set'] == 'test']

df_val, df_test, y_val, y_test = train_test_split(
    df_test[["filepaths"]], df_test["labels"], test_size=0.2,
    stratify=df_test["labels"],
)

df_val["labels"] = y_val
df_test["labels"] = y_test

print(f"{df_train.shape = }")
print(f"{df_val.shape = }")
print(f"{df_test.shape = }")
# Out:
# df_train.shape = (1200, 4)
# df_val.shape = (320, 2)
# df_test.shape = (80, 2)

# %%
plt.figure(figsize=(14, 4))

plt.subplot(1, 3, 1)
df_train["labels"].value_counts(normalize=False).plot(kind="bar")
plt.xticks(rotation=0)
plt.title("Train class count")
plt.xlabel("Class")
plt.ylabel("Image count")

plt.subplot(1, 3, 2)
df_val["labels"].value_counts(normalize=False).plot(kind="bar")
plt.xticks(rotation=0)
plt.title("Validation class count")
plt.xlabel("Class")
plt.ylabel("Image count")

plt.subplot(1, 3, 3)
df_test["labels"].value_counts(normalize=False).plot(kind="bar")
plt.xticks(rotation=0)
plt.title("Test class count")
plt.xlabel("Class")
plt.ylabel("Image count")

plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator

# Crea generadores de datos utilizando ImageDataGenerator para aumento de datos (data augmentation) si es necesario
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normaliza los valores de píxeles al rango [0, 1]
    # rotation_range=20,  # Rango de rotación aleatoria
    # width_shift_range=0.2,  # Rango de desplazamiento horizontal aleatorio
    # height_shift_range=0.2,  # Rango de desplazamiento vertical aleatorio
    # shear_range=0.2,  # Rango de deformación de corte
    # zoom_range=0.2,  # Rango de zoom aleatorio
    horizontal_flip=True,  # Volteo horizontal aleatorio
    vertical_flip=True,
    # brightness_range=(0.95, 1.05),
)

validation_split = 0.20
test_datagen = ImageDataGenerator(
    rescale=1./255,
)

# Crea generadores de datos utilizando flow_from_dataframe para cargar imágenes desde las carpetas 'train' y 'test'
train_generator = train_datagen.flow_from_dataframe(
    dataframe=df_train,
    x_col='filepaths',  # Columna que contiene las rutas de las imágenes
    y_col='labels',  # Columna que contiene las etiquetas de las imágenes
    target_size=(img_height, img_width),  # Tamaño de las imágenes (ajustar según sea necesario)
    batch_size=32,  # Tamaño del lote
    class_mode='categorical'  # Modo de clase (categórico para etiquetas codificadas one-hot)
)

val_generator = test_datagen.flow_from_dataframe(
    dataframe=df_val,
    x_col='filepaths',
    y_col='labels',
    target_size=(img_height, img_width),
    batch_size=32,
    class_mode='categorical',
    shuffle=False,
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=df_test,
    x_col='filepaths',
    y_col='labels',
    target_size=(img_height, img_width),
    batch_size=32,
    class_mode='categorical',
    shuffle=False,
)
# Out:
# Found 1200 validated image filenames belonging to 4 classes.
# Found 320 validated image filenames belonging to 4 classes.
# Found 80 validated image filenames belonging to 4 classes.

# %% [markdown]
# Puede encontrar los nombres de clase en el atributo **class_names** en estos conjuntos de datos. Estos corresponden a los nombres de los directorios en orden alfabético.

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)
# Out:
# ['Dark', 'Green', 'Light', 'Medium']

# %% [markdown]
# ## Visualiza los datos con data augmentation
#
# Aquí están las primeras nueve imágenes del conjunto de datos de entrenamiento:

# %%
nrows, ncols = 5, 5
plt.figure(figsize=(10, 10))
images, labels = next(train_generator)  # Obtiene un lote de imágenes y etiquetas del generador
for i in range(nrows*ncols):
    ax = plt.subplot(nrows, ncols, i + 1)
    plt.imshow(images[i])  # No es necesario llamar a .numpy() aquí
    plt.title(class_names[labels[i].argmax()], fontsize=11)  # Convierte etiquetas one-hot en el índice de la clase
    plt.axis("off")

plt.show()

# %%
nrows, ncols = 5, 5
plt.figure(figsize=(10, 10))
test_images, labels = next(test_generator)  # Obtiene un lote de imágenes y etiquetas del generador
for i in range(nrows*ncols):
    ax = plt.subplot(nrows, ncols, i + 1)
    plt.imshow(test_images[i])  # No es necesario llamar a .numpy() aquí
    plt.title(class_names[labels[i].argmax()], fontsize=11)  # Convierte etiquetas one-hot en el índice de la clase
    plt.axis("off")

plt.show()

# %%
for image_batch, labels_batch in train_generator:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 128, 128, 3)
# (32, 4)

# %% [markdown]
# Configurar el conjunto de datos para el rendimiento
# Asegurémonos de utilizar la captación previa almacenada en búfer para que pueda obtener datos del disco sin que la E/S se convierta en un bloqueo. Estos son dos métodos importantes que debe usar al cargar datos:
#
# * Dataset.cache mantiene las imágenes en la memoria después de que se cargan fuera del disco durante la primera época. Esto asegurará que el conjunto de datos no se convierta en un cuello de botella mientras entrena su modelo. Si su conjunto de datos es demasiado grande para caber en la memoria, también puede usar este método para crear un caché en disco de alto rendimiento.
# * Dataset.prefetch superpone el preprocesamiento de datos y la ejecución del modelo durante el entrenamiento.

# %%
# AUTOTUNE = tf.data.AUTOTUNE

# train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
# val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Crear el modelo

# %%
#pruebas
num_classes = len(class_names)

model = Sequential([
  layers.InputLayer ( input_shape=(img_height, img_width, 3) ),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),

  # layers.Flatten(),
  layers.GlobalAveragePooling2D(),
  layers.Dense(32, activation='relu'),
  layers.Dense(16, activation='relu'),
  layers.Dense(num_classes, activation="softmax"),
])
# Out:
# 2024-04-09 01:21:35.445350: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:35.589416: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:35.589515: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:35.596883: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:35.596985: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:35.597008: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:36.053580: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:36.053836: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:36.053857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-04-09 01:21:36.053957: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-09 01:21:36.054027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.compile(optimizer = 'adam',
              loss      = tf.keras.losses.CategoricalCrossentropy(),
              metrics   = ['accuracy']
              )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  global_average_pooling2d (  (None, 32)                0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 15988 (62.45 KB)
# Trainable params: 15988 (62.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# TODO: poner un visualizador de modelos

# %%
# from keras_visualizer import visualizer

# visualizer(model, file_format='png')

# %%
epochs = 15
# %time history1 = model.fit(train_generator, validation_data=val_generator, epochs=epochs, verbose=1)
# Out:
# Epoch 1/15
# 2024-04-09 01:21:45.843142: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-04-09 01:21:46.692555: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2024-04-09 01:21:49.850785: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fc166c30510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-09 01:21:49.850841: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-04-09 01:21:49.874885: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712625710.026292    1654 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 31s 583ms/step - loss: 1.3816 - accuracy: 0.2458 - val_loss: 1.3603 - val_accuracy: 0.2562
# Epoch 2/15
# 38/38 [==============================] - 21s 566ms/step - loss: 1.3015 - accuracy: 0.3325 - val_loss: 1.1788 - val_accuracy: 0.4125
# Epoch 3/15
# 38/38 [==============================] - 21s 556ms/step - loss: 0.9572 - accuracy: 0.7075 - val_loss: 0.6398 - val_accuracy: 0.8687
# Epoch 4/15
# 38/38 [==============================] - 20s 534ms/step - loss: 0.5060 - accuracy: 0.8567 - val_loss: 0.3192 - val_accuracy: 0.9281
# Epoch 5/15
# 38/38 [==============================] - 20s 514ms/step - loss: 0.2546 - accuracy: 0.9275 - val_loss: 0.1618 - val_accuracy: 0.9625
# Epoch 6/15
# 38/38 [==============================] - 20s 529ms/step - loss: 0.1756 - accuracy: 0.9458 - val_loss: 0.1535 - val_accuracy: 0.9500
# Epoch 7/15
# 38/38 [==============================] - 22s 566ms/step - loss: 0.1280 - accuracy: 0.9592 - val_loss: 0.1199 - val_accuracy: 0.9656
# Epoch 8/15
# 38/38 [==============================] - 22s 567ms/step - loss: 0.1383 - accuracy: 0.9550 - val_loss: 0.1134 - val_accuracy: 0.9656
# Epoch 9/15
# 38/38 [==============================] - 18s 471ms/step - loss: 0.1058 - accuracy: 0.9700 - val_loss: 0.1153 - val_accuracy: 0.9625
# Epoch 10/15
# 38/38 [==============================] - 6s 168ms/step - loss: 0.0898 - accuracy: 0.9675 - val_loss: 0.1244 - val_accuracy: 0.9563
# Epoch 11/15
# 38/38 [==============================] - 6s 161ms/step - loss: 0.1016 - accuracy: 0.9683 - val_loss: 0.1000 - val_accuracy: 0.9719
# Epoch 12/15
# 38/38 [==============================] - 6s 163ms/step - loss: 0.0970 - accuracy: 0.9717 - val_loss: 0.1131 - val_accuracy: 0.9625
# Epoch 13/15
# 38/38 [==============================] - 6s 168ms/step - loss: 0.0864 - accuracy: 0.9717 - val_loss: 0.0913 - val_accuracy: 0.9719
# Epoch 14/15
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0823 - accuracy: 0.9708 - val_loss: 0.1209 - val_accuracy: 0.9688
# Epoch 15/15
# 38/38 [==============================] - 6s 160ms/step - loss: 0.0881 - accuracy: 0.9692 - val_loss: 0.0969 - val_accuracy: 0.9656
# CPU times: user 1min 39s, sys: 24.9 s, total: 2min 4s
# Wall time: 3min 52s

# %% [markdown]
# # Visualiza los resultados del entrenamiento
#
# Cree gráficos de pérdida y precisión en los conjuntos de entrenamiento y validación:

# %%
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']

loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='best')
plt.ylim([0,1.1])
plt.grid(True)
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='best')
plt.grid(True)
plt.title('Training and Validation Loss')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

# Hacer predicciones en los datos de prueba
predictions = model.predict(test_generator)

# Convertir las predicciones de las etiquetas codificadas one-hot a etiquetas numéricas
predicted_labels = np.argmax(predictions, axis=1)

# Obtener las etiquetas reales de los datos de prueba
true_labels = test_generator.classes

# Calcular la matriz de confusión
confusion_mtx = confusion_matrix(true_labels, predicted_labels)

print(confusion_mtx)
# Out:
# 3/3 [==============================] - 0s 111ms/step
# [[20  0  0  0]
#  [ 0 20  0  0]
#  [ 0  0 20  0]
#  [ 1  0  0 19]]

# %%
class_names
# Out:
# ['Dark', 'Green', 'Light', 'Medium']

# %%
import seaborn as sns

# Visualizar la matriz de confusión
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
